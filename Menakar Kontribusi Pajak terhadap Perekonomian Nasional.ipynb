# %% [markdown]
# <a href="https://colab.research.google.com/github/RafiShiddik/Project/blob/main/Menakar%20Kontribusi%20Pajak%20terhadap%20Perekonomian%20Nasional.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.set_option('display.max_column', None)
pd.set_option('display.max_rows', None)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('/content/rasio-pajak-terhadap-pdb.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5 non-null      float64
#  1   Unnamed: 1  6 non-null      object
#  2   Unnamed: 2  6 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 300.0+ bytes

# %%
df.head(5)
# Out:
#    Unnamed: 0                        Unnamed: 1                    Unnamed: 2
# 0         NaN                               NaN                           NaN
# 1         NaN  Rasio Penerimaan Perpajakan  (%)  Rasio Pajak Terhadap PDB (%)
# 2      2019.0                              9.77                          8.42
# 3      2020.0                              8.32                          6.94
# 4      2021.0                              9.12                          7.53

# %%
df.column =['Tahun', 'Rasio penerimaan Perpajakan(%)', 'Rasio Pajak Terhadap PDB(%)']
# Out:
# <ipython-input-5-c4c4cd95ad52>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.column =['Tahun', 'Rasio penerimaan Perpajakan(%)', 'Rasio Pajak Terhadap PDB(%)']

# %%
print(df.column)
# Out:
# ['Tahun', 'Rasio penerimaan Perpajakan(%)', 'Rasio Pajak Terhadap PDB(%)']

# %%
df.head()
# Out:
#    Unnamed: 0                        Unnamed: 1                    Unnamed: 2
# 0         NaN                               NaN                           NaN
# 1         NaN  Rasio Penerimaan Perpajakan  (%)  Rasio Pajak Terhadap PDB (%)
# 2      2019.0                              9.77                          8.42
# 3      2020.0                              8.32                          6.94
# 4      2021.0                              9.12                          7.53

# %%
df = df.rename(columns = {
    'Unnamed: 0' : 'Tahun',
    'Unnamed: 1' : 'Rasio penerimaan Perpajakan(%)',
    'Unnamed: 2' : 'Rasio Pajak Terhadap PDB(%)'
})

# %%
df.head()
# Out:
#     Tahun    Rasio penerimaan Perpajakan(%)   Rasio Pajak Terhadap PDB(%)
# 0     NaN                               NaN                           NaN
# 1     NaN  Rasio Penerimaan Perpajakan  (%)  Rasio Pajak Terhadap PDB (%)
# 2  2019.0                              9.77                          8.42
# 3  2020.0                              8.32                          6.94
# 4  2021.0                              9.12                          7.53

# %%
df = df.dropna()
df = df.reset_index(drop = True)

# %%
df.head()
# Out:
#     Tahun Rasio penerimaan Perpajakan(%) Rasio Pajak Terhadap PDB(%)
# 0  2019.0                           9.77                        8.42
# 1  2020.0                           8.32                        6.94
# 2  2021.0                           9.12                        7.53
# 3  2022.0                          10.39                        8.76
# 4  2023.0                          10.31                        8.94

# %%
df.to_csv('hasil bersih.csv', index = False)

# %%
pip install openpyxl

# %%
df['Tahun'] = pd.to_datetime(df['Tahun'], format = '%Y')

# %%
df.to_csv('hasil bersih.csv', index = False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Tahun                           5 non-null      datetime64[ns]
#  1   Rasio penerimaan Perpajakan(%)  5 non-null      object
#  2   Rasio Pajak Terhadap PDB(%)     5 non-null      object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 252.0+ bytes
